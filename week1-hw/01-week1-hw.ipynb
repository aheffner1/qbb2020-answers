# %% [markdown]
# ## Week one: genome assembly
# ### Question 1: Coverage analysis

# %% [markdown]
# ### 1a. How long is the reference genome?

# %% [markdown]
# <font color=blue>Answer: 233806 bases </font>
# **Used command line samtools looks like this:**
#     samtools faidx ref.fa
#     ls
# *Now new file named ref.fa.fai*
#     cat ref.fa.fai
#
# Halomonas       233806  11      70      71
#
# *First column is the name of sequence*
# *Second is the length of total sequence in bases*

# %% [markdown]
# ### 1b. How many reads are provided and how long are they? Make sure to measure each file separately

# %% [markdown]
# <font color=blue> frag180.1.fq = 35178, 100
# frag180.2.fq = 35178, 100
# jump2k.1.fq = 70355, 50
# jump2k.2.fq = 70355, 50 </font>
#
# **Command line example:**
# fastqc frag180.1.fq
# ls
# *New file and folder*
# open frag180.1_fastqc.html
# Opens report in web browser
# Total sequences is the number of reads and sequences length is how long

# %% [markdown]
# ### 1c. How much coverage do you expect to have? [Hint: A little arthmetic]

# %%
# Total bases sequenced: 
total_bases_seq = 2*100*35178 + 2*50*70355
genome_length = 233806
sequence_coverage = total_bases_seq/genome_length
print(int(sequence_coverage)) # is sequence coverage normally an integer?
# Out:
# 60

# %% [markdown]
# ### 1d. Plot the average quality value across the length of the reads [We want a screenshot from FastQC]

# %% [markdown]
# ### frag180.1.fq
# ![Screen%20Shot%202020-09-11%20at%2015.15.40.png](attachment:Screen%20Shot%202020-09-11%20at%2015.15.40.png)

# %% [markdown]
# ### frag180.2.fq
# ![Screen%20Shot%202020-09-11%20at%2015.17.30.png](attachment:Screen%20Shot%202020-09-11%20at%2015.17.30.png)

# %% [markdown]
# ### jump2k.1.fq
# ![Screen%20Shot%202020-09-11%20at%2015.18.45.png](attachment:Screen%20Shot%202020-09-11%20at%2015.18.45.png)

# %% [markdown]
# ### jump2k.2.fq
# ![Screen%20Shot%202020-09-11%20at%2015.19.53.png](attachment:Screen%20Shot%202020-09-11%20at%2015.19.53.png)
